# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('itunes_data.csv', delimiter=',', skiprows=1, usecols=2, quotechar='"')
laenge_in_sekunden = [int(laenge / 1000) for laenge in data]

n, bins, _ = plt.hist(laenge_in_sekunden, bins=150, density=True)

hoechster_balken_index = np.argmax(n)
hoechster_balken_hoehe = n[hoechster_balken_index]

mittelwert = np.mean(laenge_in_sekunden)
median = np.median(laenge_in_sekunden)

plt.xlabel("Titel Länge (Sekunden)")
plt.ylabel("Relative Häufigkeit")
plt.title("Histogramm der Länge der Musiktitel")

plt.show()

print(f"Relative Häufigkeit des höchsten Balkens: {hoechster_balken_hoehe}")
print(f"Klassengrenzen: {bins[max_bar_index]} - {bins[max_bar_index + 1]} Sekunden")
print(f"Der Mittelwert: {mean_length} Sekunden")
print(f"Median: {median_length} Sekunden")
# Out:
# Relative Häufigkeit des höchsten Balkens: 0.005269477000354274
# Klassengrenzen: 212.4 - 247.63333333333333 Sekunden
# Der Mittelwert: 393.1616680948301 Sekunden
# Median: 255.0 Sekunden
